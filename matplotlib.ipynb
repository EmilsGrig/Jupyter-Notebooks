# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Imports the matplotlib pyplot extension and the numpy module. The pyplot library is used to create graphs which can be used for data analysis while numpy is used to generate numerical data.

# %% [markdown]
# The code below creates data values betweeen 0 and 100 (inclusive) and plots it onto a scatter graph.
# - plt.scatter() can take in the parameters; alpha, c, s, marker
# - alpha controls the opacity of data points and can be used to see where data overlaps
# - c allows to change the colour of the plotted data
# - s controls the size of each point
# - marker changes the style of the plot points

# %%
x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

plt.scatter(x_data, y_data, alpha=0.3)

# %% [markdown]
# Line graphs can be used to show the change in data over period of time using plt.plot() which takes in a list of x values and a list of y values aallowing to plot data linearly. The parameters it takes in (c, lw, linestyle) allow to change the style of the chart by changing the colour, width and the type of line.

# %%
years = [2006 + x for x in range(16)]
weights = [80, 83, 84, 85, 86, 82, 81, 79, 83, 80, 82, 82, 83, 81, 80, 79]

plt.plot(years, weights)

# %% [markdown]
# plt.bar() allows to plot data that is divided into groups. It takes in the parameters color, align, width, edgecolor and lw.
# - color allows to change the color of the bars
# - align allows to cahnge the starting position of each bar
# - width determines the width of each class
# - edgecolor as to provide an outline to the bars while lw allows to make the outline thicker

# %%
x = ["C++", "C#", "Python", "Java", "Go"]
y = [20, 50, 140, 1, 45]
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# To plot data on a histogram, plt.hist() used very, where a list of normally distributed data is passed through. Parameters bins and cumulative can be passed through. The parameter bins allows to change the number of bins/bars used to represent data, it is also able to take in a list which allows set custom width for a select number of bins.

# %%
ages = np.random.normal(20, 1.5, 1000)
plt.hist(ages)
# Out:
# (array([  5.,  22.,  69., 142., 233., 252., 166.,  81.,  25.,   5.]),
#  array([15.24710998, 16.18060272, 17.11409547, 18.04758821, 18.98108096,
#         19.9145737 , 20.84806645, 21.78155919, 22.71505194, 23.64854468,
#         24.58203743]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages, bins=[ages.min(), 18, 21, ages.max()])
# Out:
# (array([ 88., 663., 249.]),
#  array([15.24710998, 18.        , 21.        , 24.58203743]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(ages, cumulative=True)
# Out:
# (array([   5.,   27.,   96.,  238.,  471.,  723.,  889.,  970.,  995.,
#         1000.]),
#  array([15.24710998, 16.18060272, 17.11409547, 18.04758821, 18.98108096,
#         19.9145737 , 20.84806645, 21.78155919, 22.71505194, 23.64854468,
#         24.58203743]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Matplotlib can also be used to display data with a pie chart. It takes in the numerical value and a list of labels in order to create a simple pie chart. It can then use other parameters to represent fata more clearly, with methods such as explode which allows to seperate a specific value. Other parameters include autopct (allows to calculate and display a percentage of each group), pctdistance (determines the location of the percentage away from the center of the chart) and startangle (the starting positionof the data).

# %%
langs = ["C++", "C#", "Python", "Java", "Go"]
votes = [20, 50, 140, 5, 45]
explodes = [0,0,0,0.1,0]
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22c688b1e90>,
# ...
#  [Text(-0.2632472403313852, 1.068035996798755, 'C++'),
#   Text(-0.9740016429451693, 0.5111954611888794, 'C#'),
#   Text(0.2632473653273165, -1.0680359659900158, 'Python'),
#   Text(1.0942797094461323, 0.49249560149760546, 'Java'),
#   Text(0.569071377796735, 0.9413595311954545, 'Go')],
#  [Text(-0.14358940381711918, 0.5825650891629571, '7.69%'),
#   Text(-0.5312736234246378, 0.2788338879212069, '19.23%'),
#   Text(0.14358947199671807, -0.5825650723581904, '53.85%'),
#   Text(0.6383298305102438, 0.28728910087360315, '1.92%'),
#   Text(0.31040256970731, 0.5134688351975206, '17.31%')])

# %% [markdown]
# To create a box plot, a list of normally distributed data is passed through the function plt.boxplt()

# %%
heights = np.random.normal(172, 8, 300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22c68c29c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22c68c2b4d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22c68c291d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22c68c3c890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22c68c3d490>],
#  'means': []}

# %% [markdown]
# Box plots can be customised:

# %%
first=np.linspace(0, 10, 25)
second=np.linspace(10, 200, 25)
third=np.linspace(200, 210, 25)
fourth=np.linspace(210, 230, 25)
data=np.concatenate((first, second, third, fourth))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22c68ba1790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22c69df0750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22c69ddaf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x22c69df1750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22c69df1f90>],
#  'means': []}

# %% [markdown]
# Those are some basic and fundamental graphs, there are more advanced graphs such as heat maps, which I am yet to learn about.
#
# Plots can be customised ot show more detail about certain data by including labels, multiple plots, figures, subplots etc.

# %%
years=[2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
income=[55,56,62,61,72,72,73,75]
income_ticks=list(range(50,81,3))
plt.plot(years, income)
plt.title("Yearly Income of Sample User (in GBP)", fontsize=15, fontname="Monospace") # Sets the title of the plot
plt.xlabel("Years") # Sets the x-axis label
plt.ylabel("Yearly Income") # Sets the y-axis label
plt.yticks(income_ticks, [f"£{x}k" for x in income_ticks]) # Alters the y-axis labels to be mopre representative of the data
# Out:
# ([<matplotlib.axis.YTick at 0x22c6f6ec050>,
# ...
#  [Text(0, 50, '£50k'),
#   Text(0, 53, '£53k'),
#   Text(0, 56, '£56k'),
#   Text(0, 59, '£59k'),
#   Text(0, 62, '£62k'),
#   Text(0, 65, '£65k'),
#   Text(0, 68, '£68k'),
#   Text(0, 71, '£71k'),
#   Text(0, 74, '£74k'),
#   Text(0, 77, '£77k'),
#   Text(0, 80, '£80k')])

# %% [markdown]
# As I stated earlier, matplotlib can be used to represnt multiple plots at once, this can be done with the following code:

# %%
stock_a=[100,102,99,101,101,100,102]
stock_b=[90,95,102,104,105,103,109]
stock_c=[110,115,100,105,100,98,95]

plt.plot(stock_a, label="Company 1")
plt.plot(stock_b, label="Company 2")
plt.plot(stock_c, label="Company 3")

plt.legend(loc="lower right") # Provides a key for each plot, making it more understandable
plt.xlabel("Years")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
votes = [10,2,5,16,22]
people=["A","B","C","D","E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

# %% [markdown]
# For further styling, import style from matplotlib in order to use stylesheets.

# %%
from matplotlib import style

style.use("ggplot") #Changes the stylesheet of the plots

plt.pie(votes, labels=None)
plt.legend(labels=people)

# %%
style.use("dark_background")
plt.pie(votes)
# Out:
# ([<matplotlib.patches.Wedge at 0x22c6fb6c3d0>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, ''),
#   Text(0.3399186619790915, 1.046162178267951, ''),
#   Text(-0.09413254803929685, 1.095964900623934, ''),
#   Text(-1.0554422755920454, 0.30990579680458524, ''),
#   Text(0.3399186987098807, -1.0461621663333946, '')])

# %% [markdown]
# List of stylesheests: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
style.use("default")
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)

# Figure allows to visualise 2 different plots on two seperate graphs

plt.figure(2)
plt.plot(x2, y2)

# %% [markdown]
# Subplots allows to have multiple graph within a single image/window.

# %%
x = np.arange(100)
fig, axs =plt.subplots(2,2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title("Sine Graph of X")

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title("Cosine Graph of X")

axs[1,0].plot(x, np.random.random(100))
axs[1,0].set_title("Rndom Function of X")

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title("Logarithm Graph of X")
axs[1,1].set_xlabel("Test")

plt.tight_layout() # Provides space to avoid overlapping

fig.suptitle("Four Plots")
# Out:
# C:\Users\Emil\AppData\Local\Temp\ipykernel_11004\3516028929.py:13: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))
# Text(0.5, 0.98, 'Four Plots')

# %% [markdown]
# To export graphs, you would use the plt.savefig() function.
# For example:

# %%
plt.savefig("fourplots.png", dpi=300, transparent=False) # dpi parameter allows for higher quality

# %% [markdown]
# The matplotlib library allows for 3d plottting.
# Using this feature otuside a notebook allows to rotate the graph, instead of having a single static image, since an interactable window is created.

# %%
ax = plt.axes(projection="3d")

x=np.random.random(100)
y=np.random.random(100)
z=np.random.random(100)

ax.scatter(x,y,z)
ax.set_title("3D Plot")
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
ax = plt.axes(projection="3d")

x=np.arange(0, 50, 0.1)
y=np.sin(x)
z=np.cos(x)

ax.plot(x,y,z)

# %%
ax = plt.axes(projection="3d")

x=np.arange(-5, 5, 0.1)
y=np.arange(-1, 5, 0.1)

X,Y = np.meshgrid(x,y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X,Y,Z, cmap="Spectral")

# %% [markdown]
# To view at a different angle:

# %%
ax = plt.axes(projection="3d")
ax.plot_surface(X,Y,Z, cmap="Spectral")
ax.view_init(azim=0, elev=90)

# %% [markdown]
# Plots can be animated. In the following example, a coin is flipped with the graph constantly updated to display and keep track of the results. It is better for the followng code to be run outside of this jupyter notebook.

# %%
import random
heads_tails = [0,0]
for i in range(100000):
    heads_tails[random.randint(0,1)] += 1
    plt.bar(["Heads", "tails"], heads_tails, color=["red", "blue"])
    plt.pause(0.001)
